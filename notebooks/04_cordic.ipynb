# %% [markdown]
# ## Contents
#
# 1. [Motivation](#motivation)
# 2. [Mathematical Foundation](#mathematical-foundation)
# 3. [Hardware-Oriented Formulation](#hardware-oriented-formulation)
# 4. [Numerical Validation](#numerical-validation)
# 5. [Block-Level Hardware Architecture](#block-level-hardware-architecture)

# %% [markdown]
# <a id="motivation"></a>
#
# ## Motivation

# %% [markdown]
# <a id="mathematical-foundation"></a>
#
# ## Mathematical Foundation

# %% [markdown]
# <a id="hardware-oriented-formulation"></a>
#
# ## Hardware-Oriented Formulation

# %% [markdown]
# <a id="block-level-hardware-architecture"></a>
#
# ## Block-Level Hardware Architecture
